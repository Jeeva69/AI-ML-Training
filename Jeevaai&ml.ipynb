# %%
import numpy as np

# %%
import pandas as pd

# %%
np.random.seed(42)

# %%
apartments=[f"Apt_{i}" for i in range(1,21)]

# %%
Dates=pd.date_range(start="2025-07-01",periods=30,freq="D")

# %%
Data={
    "Date":np.tile(Dates,len(apartments)),
    "Apartment":np.repeat(apartments,len(Dates)),
    "Electricity_usage":np.random.normal(loc=20,scale=5,size=len(Dates)*len(apartments))
}

# %%
df=pd.DataFrame(Data)
df
# Out:
#           Date Apartment  Electricity_usage
# 0   2025-07-01     Apt_1          22.483571
# 1   2025-07-02     Apt_1          19.308678
# 2   2025-07-03     Apt_1          23.238443
# 3   2025-07-04     Apt_1          27.615149
# 4   2025-07-05     Apt_1          18.829233
# ..         ...       ...                ...
# 595 2025-07-26    Apt_20          17.449918
# 596 2025-07-27    Apt_20          18.650625
# 597 2025-07-28    Apt_20          15.106181
# 598 2025-07-29    Apt_20          17.778534
# 599 2025-07-30    Apt_20          21.886502
#
# [600 rows x 3 columns]

# %%
daily_avg=df.groupby("Date")["Electricity_usage"].mean()
print(daily_avg.head)
# Out:
# <bound method NDFrame.head of Date
# 2025-07-01    21.043539
# 2025-07-02    20.870132
# 2025-07-03    19.567646
# 2025-07-04    20.985517
# 2025-07-05    19.782940
# 2025-07-06    19.378790
# 2025-07-07    20.217539
# 2025-07-08    19.257432
# 2025-07-09    20.026877
# 2025-07-10    19.378639
# 2025-07-11    18.583965
# 2025-07-12    20.734315
# 2025-07-13    21.806385
# 2025-07-14    19.903964
# 2025-07-15    19.895329
# 2025-07-16    19.869134
# 2025-07-17    19.625928
# 2025-07-18    19.513570
# 2025-07-19    20.177895
# 2025-07-20    16.908401
# 2025-07-21    19.949131
# 2025-07-22    20.073323
# 2025-07-23    17.306597
# 2025-07-24    21.301705
# 2025-07-25    20.179495
# 2025-07-26    19.113602
# 2025-07-27    19.725822
# 2025-07-28    19.391965
# 2025-07-29    21.302088
# 2025-07-30    22.100444
# Name: Electricity_usage, dtype: float64>

# %%
print(df.dtypes)
# Out:
# Date                 datetime64[ns]
# Apartment                    object
# Electricity_usage           float64
# dtype: object

# %%
usage_per_apartment = df.groupby("Apartment")["Electricity_usage"].sum().sort_values(ascending=False)

# %%
print(usage_per_apartment)
# Out:
# Apartment
# Apt_11    642.282391
# Apt_6     641.817993
# Apt_13    634.225898
# Apt_10    616.074819
# Apt_20    613.164300
# Apt_7     609.838848
# Apt_8     607.205434
# Apt_16    606.985293
# Apt_14    604.314773
# Apt_3     601.932716
# Apt_4     596.962256
# Apt_15    591.394231
# Apt_19    586.585246
# Apt_5     585.756283
# Apt_2     581.825629
# Apt_9     578.485218
# Apt_1     571.777966
# Apt_17    570.315585
# Apt_12    569.016727
# Apt_18    549.480581
# Name: Electricity_usage, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=usage_per_apartment.index,y=usage_per_apartment)
plt.xticks(rotation=90)
plt.title("Total usage per Apartments")
plt.xlabel("Apartments")
plt.ylabel("Total KWH")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=daily_avg.index, y=daily_avg.values)
plt.title("Daily Average Electricity Usage")
plt.xlabel("Date")
plt.ylabel("Average kwh")
plt.tight_layout()
plt.show()

# %%
# Assuming daily_avg is a DataFrame with index as datetime and a 'value' column
# If the index is datetime, convert to numeric for plotting
x = pd.to_datetime(daily_avg.index)
y = daily_avg.values
z = np.arange(len(daily_avg))  # using index as z-axis

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Convert datetime to float (ordinal format) for x-axis
x_numeric = x.map(pd.Timestamp.toordinal)

# 3D line plot
ax.plot(x_numeric, y, z, label='Electricity Usage', color='blue')

# Format axes
ax.set_title("3D Daily Average Electricity Usage")
ax.set_xlabel("Date")
ax.set_ylabel("Average kWh")
ax.set_zlabel("Index (Time Progression)")

# Optional: Format x-axis back to readable date labels
ax.set_xticks(x_numeric[::len(x)//5])  # reduce ticks to avoid clutter
ax.set_xticklabels(x[::len(x)//5].strftime('%Y-%m-%d'), rotation=30, ha='right')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Gowshika Varshini\AppData\Local\Temp\ipykernel_20624\3838237437.py:26: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
